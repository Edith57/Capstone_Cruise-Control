# %% [markdown]
# <a href="https://colab.research.google.com/github/Edith57/Capstone_Cruise-Control/blob/main/YOLOv5_0215.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/yolov5/KITTI
# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/yolov5/KITTI
# /content/drive/MyDrive/yolov5/KITTI

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.10 MiB | 8.67 MiB/s, done.
# Resolving deltas: 100% (11855/11855), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 52.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 40.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 28.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.4 MB/s eta 0:00:00
# ...

# %%
# !mv /content/yolov5 /content/drive/MyDrive/yolov5

# %% [markdown]
# https://somsoming9.tistory.com/16
#
#
# https://velog.io/@jjanggu84/YOLOv8-Kitti-Dataset-Training  추천!!
#
# https://velog.io/@openjr/YOLO-v5-KITTI-%ED%95%99%EC%8A%B5-%EC%8B%9C%ED%82%A4%EA%B8%B0 추천2_키티

# %%
# !mkdir -p training/images
# !mkdir -p training/labels
# !mkdir -p testing/images
# 폴더 트리 구조 생성

# %%
# !mkdir temp_images
# !unzip -o data_object_image_2.zip -d temp_images
# 임시폴더에서 압출 풀기
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  extracting: temp_images/testing/image_2/003183.png
#  extracting: temp_images/testing/image_2/007384.png
#  extracting: temp_images/testing/image_2/002195.png
#  extracting: temp_images/testing/image_2/002058.png
#  extracting: temp_images/testing/image_2/006043.png
#  extracting: temp_images/testing/image_2/006951.png
#  extracting: temp_images/testing/image_2/002983.png
#  extracting: temp_images/testing/image_2/007502.png
#  extracting: temp_images/testing/image_2/007116.png
#  extracting: temp_images/testing/image_2/006136.png
#  extracting: temp_images/testing/image_2/006982.png
#  extracting: temp_images/testing/image_2/000618.png
#  extracting: temp_images/testing/image_2/005595.png
#  extracting: temp_images/testing/image_2/000198.png
#  extracting: temp_images/testing/image_2/005881.png
#  extracting: temp_images/testing/image_2/005327.png
#  extracting: temp_images/testing/image_2/005955.png
# ...
